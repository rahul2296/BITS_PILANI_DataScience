# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sb
 
data = [11, 22, 20, 14, 29, 8, 35, 27, 13, 49, 10, 24, 17]
print(data)
data.sort()
print(data)

length = len(data)
if(length % 2 == 0):
	median = (data[int(length/2 - 1)] + data[int(length/2)]) / 2
else:
	median = data[int(length/2)]


print("length: ", length)
print("midpoint: ", length/2)
print("median: (Q2) ", median)
# Out:
# [11, 22, 20, 14, 29, 8, 35, 27, 13, 49, 10, 24, 17]
# [8, 10, 11, 13, 14, 17, 20, 22, 24, 27, 29, 35, 49]
# length:  13
# midpoint:  6.5
# median: (Q2)  20

# %%
import seaborn as sns

plt.figure(figsize=(15,8))
box_plot = sb.boxplot(data = data, linewidth = 1.5)
